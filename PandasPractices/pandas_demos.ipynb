# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv")

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 84)
pd.set_option('display.max_rows', 78)

# %%
df_schema = pd.read_csv('data/survey_results_schema.csv')

# %%
df_schema
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.tail()
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89179     25-34 years old  Employed, full-time;Independent contractor, fr...
# 89180     18-24 years old             Student, full-time;Employed, part-time
# 89181   Prefer not to say                                I prefer not to say
# 89182  Under 18 years old             Employed, part-time;Student, part-time
# 89183     35-44 years old                                Employed, full-time
#
#                                  RemoteWork  \
# 89179                                Remote
# 89180  Hybrid (some remote, some in-person)
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Employment']
# Out:
# 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
df['Employment'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                                      NaN
# 1                                      Employed, full-time
# 2                                      Employed, full-time
# 3                                      Employed, full-time
# 4        Employed, full-time;Independent contractor, fr...
#                                ...
# 89179    Employed, full-time;Independent contractor, fr...
# 89180               Student, full-time;Employed, part-time
# 89181                                  I prefer not to say
# 89182               Employed, part-time;Student, part-time
# 89183                                  Employed, full-time
# Name: Employment, Length: 89184, dtype: object>

# %%
df.loc[[0,1,2,3], 'Employment']
# Out:
# 0                    NaN
# 1    Employed, full-time
# 2    Employed, full-time
# 3    Employed, full-time
# Name: Employment, dtype: object

# %%
df.loc[0:5, 'Employment':'YearsCode']
# Out:
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
# 5                                Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
# ...

# %%
filt = (df['Employment'] == 'Employed, full-time')

# %%
df[filt]
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 5               6  I agree  I am a developer by profession  35-44 years old
# 6               7  I agree  I am a developer by profession  35-44 years old
# ...           ...      ...                             ...              ...
# 89174       89175  I agree  I am a developer by profession  18-24 years old
# 89175       89176  I agree  I am a developer by profession  25-34 years old
# 89177       89178  I agree  I am a developer by profession  35-44 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
# 89183       89184  I agree  I am a developer by profession  35-44 years old
#
# ...

# %%
df.loc[filt, 'Age']
# Out:
# 1        25-34 years old
# 2        45-54 years old
# 3        25-34 years old
# 5        35-44 years old
# 6        35-44 years old
#               ...
# 89174    18-24 years old
# 89175    25-34 years old
# 89177    35-44 years old
# 89178    45-54 years old
# 89183    35-44 years old
# Name: Age, Length: 53748, dtype: object

# %%
df.loc[filt, 'Age':'EdLevel']
# Out:
#                    Age           Employment  \
# 1      25-34 years old  Employed, full-time
# 2      45-54 years old  Employed, full-time
# 3      25-34 years old  Employed, full-time
# 5      35-44 years old  Employed, full-time
# 6      35-44 years old  Employed, full-time
# ...                ...                  ...
# 89174  18-24 years old  Employed, full-time
# 89175  25-34 years old  Employed, full-time
# 89177  35-44 years old  Employed, full-time
# 89178  45-54 years old  Employed, full-time
# 89183  35-44 years old  Employed, full-time
#
#                                  RemoteWork  \
# 1                                    Remote
# 2      Hybrid (some remote, some in-person)
# 3      Hybrid (some remote, some in-person)
# 5                                    Remote
# 6                                    Remote
# ...                                     ...
# 89174                             In-person
# 89175                                Remote
# ...

# %%
df['Country']
# Out:
# 0                                 NaN
# 1            United States of America
# 2            United States of America
# 3            United States of America
# 4                         Philippines
#                      ...
# 89179                          Brazil
# 89180                         Romania
# 89181                          Israel
# 89182                     Switzerland
# 89183    Iran, Islamic Republic of...
# Name: Country, Length: 89184, dtype: object

# %%
country_list = ['United States of America', 'Brazil', 'Switzerland', 'Romania']
coutry_filter = df['Country'].isin(country_list)

# %%
df.loc[coutry_filter, 'Country']
# Out:
# 1        United States of America
# 2        United States of America
# 3        United States of America
# 6        United States of America
# 7        United States of America
#                    ...
# 89175    United States of America
# 89178    United States of America
# 89179                      Brazil
# 89180                     Romania
# 89182                 Switzerland
# Name: Country, Length: 22667, dtype: object

# %%
language_filter = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[language_filter, 'LanguageHaveWorkedWith']
# Out:
# 1                               HTML/CSS;JavaScript;Python
# 7        Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 9           HTML/CSS;Java;JavaScript;Python;SQL;TypeScript
# 10                       C#;C++;HTML/CSS;JavaScript;Python
# 11       C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
#                                ...
# 89172    Bash/Shell (all shells);HTML/CSS;JavaScript;Pe...
# 89176    HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeSc...
# 89180                                 Dart;Java;Python;SQL
# 89181    Assembly;Bash/Shell (all shells);C;C#;Python;R...
# 89182    Bash/Shell (all shells);C#;HTML/CSS;Java;JavaS...
# Name: LanguageHaveWorkedWith, Length: 43158, dtype: object

# %%
df.rename(columns = {'ConvertedCompYearly' : 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# 0             NaN
# 1        285000.0
# 2        250000.0
# 3        156000.0
# 4         23456.0
#            ...
# 89179         NaN
# 89180         NaN
# 89181         NaN
# 89182         NaN
# 89183         NaN
# Name: SalaryUSD, Length: 89184, dtype: float64

# %%
df['Q120'] = df['Q120'].replace({'I agree' : 'Agree'})

# %%
df['Q120']
# Out:
# 0        Agree
# 1        Agree
# 2        Agree
# 3        Agree
# 4        Agree
#          ...
# 89179    Agree
# 89180    Agree
# 89181    Agree
# 89182    Agree
# 89183    Agree
# Name: Q120, Length: 89184, dtype: object

# %%
df.sort_values(by=['Country', 'SalaryUSD'], ascending=[False, False], inplace=True)

# %%
df[['Country','SalaryUSD']]
# Out:
#         Country  SalaryUSD
# 81950  Zimbabwe   114000.0
# 52878  Zimbabwe    60000.0
# 47465  Zimbabwe    30000.0
# 64106  Zimbabwe    15000.0
# 64949  Zimbabwe    15000.0
# ...         ...        ...
# 88820       NaN        NaN
# 88828       NaN        NaN
# 88830       NaN        NaN
# 89028       NaN        NaN
# 89159       NaN        NaN
#
# [89184 rows x 2 columns]

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# 53268    74351432.0
# 77848    73607918.0
# 66223    72714292.0
# 28121    57513831.0
# 19679    36573181.0
# 55102    17612921.0
# 80586    11000000.0
# 83679    10319366.0
# 47797     9915585.0
# 88347     9203683.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#        ResponseId   Q120                                         MainBranch  \
# 53268       53269  Agree                     I am a developer by profession
# 77848       77849  Agree                     I am a developer by profession
# 66223       66224  Agree                     I am a developer by profession
# 28121       28122  Agree                     I am a developer by profession
# 19679       19680  Agree                     I am a developer by profession
# 55102       55103  Agree  I am not primarily a developer, but I write co...
# 80586       80587  Agree                     I am a developer by profession
# 83679       83680  Agree                     I am a developer by profession
# 47797       47798  Agree                     I am a developer by profession
# 88347       88348  Agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#        ResponseId   Q120                                         MainBranch  \
# 5724         5725  Agree                     I am a developer by profession
# 8862         8863  Agree                     I am a developer by profession
# 3929         3930  Agree                     I am a developer by profession
# 37314       37315  Agree                     I am a developer by profession
# 54023       54024  Agree                     I am a developer by profession
# 82495       82496  Agree  I am not primarily a developer, but I write co...
# 37160       37161  Agree                     I am a developer by profession
# 55664       55665  Agree                     I am a developer by profession
# 87480       87481  Agree                     I am a developer by profession
# 13708       13709  Agree                     I am a developer by profession
#
#                    Age                                         Employment  \
# ...

# %%
df['SalaryUSD'].median()
# Out:
# 74963.0

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp     SalaryUSD
# count  89184.000000  4.822500e+04  43579.000000  4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126  1.031101e+05
# std    25745.347541  2.276847e+44      9.051989  6.814188e+05
# min        1.000000  0.000000e+00      0.000000  1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000  4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000  7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000  1.216410e+05
# max    89184.000000  5.000000e+46     50.000000  7.435143e+07

# %%
df['Q120'].count()
# Out:
# 89184

# %%
df['Employment'].value_counts()
# Out:
# Employment
# Employed, full-time                                                                                                                                                                                             53748
# Student, full-time                                                                                                                                                                                               7430
# Independent contractor, freelancer, or self-employed                                                                                                                                                             7076
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                                                                                         4354
# ...

# %%
df['Knowledge_8'].value_counts(normalize=True)
# Out:
# Knowledge_8
# Agree                         0.396822
# Neither agree nor disagree    0.264660
# Disagree                      0.169235
# Strongly agree                0.111245
# Strongly disagree             0.058038
# Name: proportion, dtype: float64

# %%
df['Country']
# Out:
# 81950    Zimbabwe
# 52878    Zimbabwe
# 47465    Zimbabwe
# 64106    Zimbabwe
# 64949    Zimbabwe
#            ...
# 88820         NaN
# 88828         NaN
# 88830         NaN
# 89028         NaN
# 89159         NaN
# Name: Country, Length: 89184, dtype: object

# %%
 country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
# C:\Users\maria\AppData\Local\Temp\ipykernel_11600\421256909.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_grp.get_group('India')
#        ResponseId   Q120                                         MainBranch  \
# 72665       72666  Agree                     I am a developer by profession
# 46337       46338  Agree                     I am a developer by profession
# 86268       86269  Agree  I am not primarily a developer, but I write co...
# 85853       85854  Agree                     I am a developer by profession
# 9999        10000  Agree                     I am a developer by profession
# ...           ...    ...                                                ...
# 89068       89069  Agree  I am not primarily a developer, but I write co...
# ...

# %%
country_filt = (df['Country'] == 'India')

# %%
df.loc[country_filt]['Knowledge_8'].value_counts()
# Out:
# Knowledge_8
# Agree                         1084
# Neither agree nor disagree     678
# Strongly agree                 334
# Disagree                       282
# Strongly disagree              112
# Name: count, dtype: int64

# %%
country_grp['Knowledge_8'].value_counts().loc['India']
# Out:
# Knowledge_8
# Agree                         1084
# Neither agree nor disagree     678
# Strongly agree                 334
# Disagree                       282
# Strongly disagree              112
# Name: count, dtype: int64

# %%
country_grp['SalaryUSD'].median()
# Out:
# Country
# Afghanistan                               915.0
# Albania                                 10741.0
# Algeria                                  8782.0
# Andorra                                 42836.0
# Angola                                   4302.0
#                                          ...
# Venezuela, Bolivarian Republic of...    12000.0
# Viet Nam                                12763.0
# Yemen                                    6500.0
# Zambia                                   9687.0
# Zimbabwe                                12500.0
# Name: SalaryUSD, Length: 185, dtype: float64

# %%
country_grp['SalaryUSD'].agg(['mean', 'median'])
# Out:
#                                                mean   median
# Country
# Afghanistan                           843636.090909    915.0
# Albania                                29219.450000  10741.0
# Algeria                                10069.190476   8782.0
# Andorra                               120368.800000  42836.0
# Angola                                  4302.000000   4302.0
# ...                                             ...      ...
# Venezuela, Bolivarian Republic of...   23068.851852  12000.0
# Viet Nam                               20995.956140  12763.0
# Yemen                                  15089.333333   6500.0
# Zambia                                 13897.800000   9687.0
# Zimbabwe                               26740.000000  12500.0
#
# [185 rows x 2 columns]

# %%
country_grp['WebframeHaveWorkedWith'].apply(lambda x: x.str.contains('js').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  24
# Algeria                                  42
# Andorra                                   5
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     72
# Viet Nam                                192
# Yemen                                     9
# Zambia                                   13
# Zimbabwe                                 15
# Name: WebframeHaveWorkedWith, Length: 185, dtype: int64

# %%
country_list = df['Country'].value_counts()
country_list
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Liechtenstein                                               1
# Samoa                                                       1
# Saint Kitts and Nevis                                       1
# Guinea-Bissau                                               1
# Central African Republic                                    1
# Name: count, Length: 185, dtype: int64

# %%
know_python_list = country_grp['WebframeHaveWorkedWith'].apply(lambda x: x.str.contains('js').sum())
know_python_list
# Out:
# Country
# Afghanistan                              20
# Albania                                  24
# Algeria                                  42
# Andorra                                   5
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     72
# Viet Nam                                192
# Yemen                                     9
# Zambia                                   13
# Zimbabwe                                 15
# Name: WebframeHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat([country_list, know_python_list], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18647
# Germany                                              7328
# India                                                5625
# United Kingdom of Great Britain and Northern Ir...   5552
# Canada                                               3507
# ...                                                   ...
# Liechtenstein                                           1
# Samoa                                                   1
# Saint Kitts and Nevis                                   1
# Guinea-Bissau                                           1
# Central African Republic                                1
#
#                                                     WebframeHaveWorkedWith
# Country
# United States of America                                              7754
# Germany                                                               3037
# ...

# %%
python_df.rename(columns={'count': 'NumResponded', 'WebframeHaveWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                                                     NumResponded  \
# Country
# United States of America                                   18647
# Germany                                                     7328
# India                                                       5625
# United Kingdom of Great Britain and Northern Ir...          5552
# Canada                                                      3507
# ...                                                          ...
# Liechtenstein                                                  1
# Samoa                                                          1
# Saint Kitts and Nevis                                          1
# Guinea-Bissau                                                  1
# Central African Republic                                       1
#
#                                                     NumKnowsPython
# Country
# United States of America                                      7754
# ...

# %%
python_df['PercentKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumResponded']) * 100

# %%
python_df
# Out:
#                                                     NumResponded  \
# Country
# United States of America                                   18647
# Germany                                                     7328
# India                                                       5625
# United Kingdom of Great Britain and Northern Ir...          5552
# Canada                                                      3507
# ...                                                          ...
# Liechtenstein                                                  1
# Samoa                                                          1
# Saint Kitts and Nevis                                          1
# Guinea-Bissau                                                  1
# Central African Republic                                       1
#
#                                                     NumKnowsPython  \
# Country
# United States of America                                      7754
# ...

# %%
python_df.sort_values(by='PercentKnowsPython', ascending=False)
# Out:
#                                   NumResponded  NumKnowsPython  \
# Country
# Gabon                                        2               2
# Congo, Republic of the...                    2               2
# Saint Kitts and Nevis                        1               1
# Senegal                                     13              11
# Maldives                                    12              10
# ...                                        ...             ...
# Saint Vincent and the Grenadines             2               0
# Monaco                                       2               0
# Guinea                                       2               0
# Timor-Leste                                  2               0
# Central African Republic                     1               0
#
#                                   PercentKnowsPython
# Country
# Gabon                                     100.000000
# Congo, Republic of the...                 100.000000
# ...
